# %% [markdown]
# ![data](https://storage.googleapis.com/kaggle-datasets-images/7714230/12337688/a00eb373e4b69662d751facf5b847d14/dataset-cover.png?t=2025-07-01-07-46-53)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as w
w.filterwarnings('ignore')

# %% [markdown]
# # Load File

# %%
df=pd.read_csv('salaries.csv')

# %% [markdown]
# # Data Analysis
#
# Here, we will look for any discrepancies and correct any issues we find.

# %% [markdown]
# ## 1> Getting shape of the dataset
#
# `df.shape`

# %%
df.shape
# Out:
# (141566, 11)

# %% [markdown]
# Dataset has *141k rows and 11 columns*.<br>
# The dataset is of descet size

# %% [markdown]
# ## 2> Looking at data [just a vauge sense of what our dataset looks like]
#
# `df.head()`

# %%
df.head()
# Out:
#    work_year experience_level employment_type             job_title  salary  \
# 0       2025               EN              FT  Data Quality Analyst   60000
# 1       2025               EN              FT  Data Quality Analyst   48000
# 2       2025               SE              FT     Applied Scientist  266000
# 3       2025               SE              FT     Applied Scientist  204000
# 4       2025               SE              FT        Data Scientist  291000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             GBP          75949                 GB             0
# 1             GBP          60759                 GB             0
# 2             USD         266000                 US             0
# 3             USD         204000                 US             0
# 4             USD         291000                 US             0
#
#   company_location company_size
# 0               GB            M
# 1               GB            M
# 2               US            M
# 3               US            M
# 4               US            M

# %% [markdown]
# ### 🧾 Column Descriptions
#
# #### `work_year`
# The year the salary was reported. Covers salaries from 2020 through 2025.
#
# #### `experience_level`
# The seniority level of the employee at the time of reporting. Common values include:
# - `EN`: Entry-level / Junior
# - `MI`: Mid-level / Intermediate
# - `SE`: Senior-level
# - `EX`: Executive / Director
#
# #### `employment_type`
# The type of employment contract:
# - `FT`: Full-time
# - `PT`: Part-time
# - `CT`: Contract
# - `FL`: Freelance
#
# #### `job_title`
# The employee’s specific job title (e.g., Data Scientist, ML Engineer, AI Specialist, Research Scientist).
#
# #### `salary`
# The employee's gross annual salary in the original reported currency, before taxes and deductions.
#
# #### `salary_currency`
# The currency in which the salary was originally paid (e.g., USD, EUR, INR).
#
# #### `salary_in_usd`
# The employee's salary converted into USD using 2025 exchange rates for standardized comparison.
#
# #### `employee_residence`
# The country (ISO 3166-1 alpha-2 code) where the employee resides. This may differ from the company location, especially in remote roles.
#
# #### `remote_ratio`
# Indicates the percentage of remote work:
# - `0`: No remote work (On-site)
# - `50`: Hybrid (partially remote)
# - `100`: Fully remote
#
# #### `company_location`
# The country (ISO 3166-1 alpha-2 code) where the company or employer is headquartered.
#
# #### `company_size`
# The size of the employing organization:
# - `S`: Small (1–50 employees)
# - `M`: Medium (51–500 employees)
# - `L`: Large (501+ employees)

# %% [markdown]
# ## 3> Overview Using `df.info()`
#
# Displays a concise summary of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141566 entries, 0 to 141565
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           141566 non-null  int64
#  1   experience_level    141566 non-null  object
#  2   employment_type     141566 non-null  object
#  3   job_title           141566 non-null  object
#  4   salary              141566 non-null  int64
#  5   salary_currency     141566 non-null  object
#  6   salary_in_usd       141566 non-null  int64
#  7   employee_residence  141566 non-null  object
#  8   remote_ratio        141566 non-null  int64
#  9   company_location    141566 non-null  object
#  10  company_size        141566 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 11.9+ MB

# %% [markdown]
# ## 4> Checking for null values
#
# `df.isnull().sum()`

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# The dataset is clean, no null values

# %% [markdown]
# ## 5> Formatting `work_year` and `salary_in_usd` dtypes

# %%
df['work_year']=df['work_year'].astype(str)
df['work_year'] = pd.to_datetime(df['work_year'], format='%Y')
df['salary_in_usd']=df['salary_in_usd'].astype(int)

# %% [markdown]
# Converting `work_year` dtype from `int` to `str` <br>
# Converting `work_year` dtype from `str` to `datetime` <br>
# Converting `salary_in_usd` dtype to `integer`

# %% [markdown]
# ## 6> Formatting `salary` and `salary_in_usd` columns

# %%
df=df.drop('salary',axis=1) 
df=df.rename(columns={'salary_in_usd':'salary'})

# %% [markdown]
# Dropping `salary` as it is redundent<br>
# Renaming `salary_in_usd` to `salary` for better understanding

# %% [markdown]
# ## 7> Data Understanding

# %%
df.groupby('experience_level').agg({'salary': ['mean','max','min'],
                                                              'company_size':['min','max','count']})
# Out:
#                          salary                company_size
#                            mean     max    min          min max  count
# experience_level
# EN                 98995.354826  793136  15000            L   S  13167
# EX                201656.359484  625000  15000            L   S   3569
# MI                142825.852397  800000  15000            L   S  42865
# SE                172644.073202  800000  15645            L   S  81965

# %% [markdown]
# #### Key Insights:
#
# - **Executives (EX)** earn the **highest average salary**,but their count is the lowes <br>
# - **Entry-level (EN)** employees have the **lowest average salary**, but surprisingly, some reached up to <br>                        **$793k** — likely outliers or unusual cases.
# - **Senior-level (SE)** and **Mid-level (MI)** roles dominate in numbers, showing these are the most common in the dataset.
# - **Company size min/max being L to S** across all groups suggests a mix of small to large companies hire at all experience levels.

# %%
df.loc[(df['experience_level']=='MI') & (df['salary']>600000)]
# Out:
#         work_year experience_level employment_type  \
# 4291   2025-01-01               MI              FT
# 10244  2025-01-01               MI              FT
# 14393  2025-01-01               MI              FT
# 24753  2025-01-01               MI              FT
# 27883  2025-01-01               MI              FT
# 30343  2025-01-01               MI              FT
# 30818  2025-01-01               MI              FT
# 31365  2025-01-01               MI              FT
# 32773  2025-01-01               MI              FT
# 33641  2025-01-01               MI              FT
# 44682  2025-01-01               MI              FT
# 44698  2025-01-01               MI              FT
# 46838  2025-01-01               MI              FT
# 51405  2025-01-01               MI              FT
# 52211  2025-01-01               MI              FT
# 55446  2025-01-01               MI              FT
# 56467  2025-01-01               MI              FT
# 57717  2025-01-01               MI              FT
# 61463  2025-01-01               MI              FT
# 63301  2025-01-01               MI              FT
# 63302  2025-01-01               MI              FT
# 63469  2025-01-01               MI              FT
# 63986  2025-01-01               MI              FT
# 63998  2025-01-01               MI              FT
# 65318  2025-01-01               MI              FT
# 117289            Software Engineer             USD  720000
# 120059            Research Engineer             USD  720000
# 120061            Research Engineer             USD  720000
# 122029           Analytics Engineer             USD  720000
# 127175   Machine Learning Scientist             USD  720000
# 127836                 AI Architect             USD  800000
# 128687           Analytics Engineer             USD  720000
# 129654   Machine Learning Scientist             USD  750000
# 130840   Machine Learning Scientist             USD  750000
# 130870            Research Engineer             USD  720000
# 130880           Research Scientist             USD  720000
# 130884            Research Engineer             USD  720000
# 131438   Machine Learning Scientist             USD  750000
# 131444    Machine Learning Engineer             USD  750000
# 132374           Analytics Engineer             USD  700000
# 132422                Data Engineer             USD  750000
#
#        employee_residence  remote_ratio company_location company_size
# 4291                   US             0               US            M
# 10244                  NL             0               NL            M
# 14393                  US           100               US            M
# 24753                  US           100               US            M
# 27883                  US           100               US            M
# 30343                  US           100               US            M
# 30818                  US           100               US            M
# 31365                  US           100               US            M
# 32773                  US             0               US            M
# 33641                  US             0               US            M
# 44682                  US           100               US            M
# 44698                  US           100               US            M
# 46838                  US           100               US            M
# 51405                  US           100               US            M
# 52211                  US           100               US            M
# 55446                  GB             0               GB            M
# 56467                  US           100               US            M
# 57717                  US           100               US            M
# 61463                  US           100               US            M
# 63301                  GB             0               GB            M
# 63302                  GB             0               GB            M
# 63469                  US           100               US            M
# 63986                  US             0               US            M
# 63998                  US           100               US            M
# 65318                  US           100               US            M
# 66520                  US           100               US            M
# 66522                  US           100               US            M
# 68824                  US             0               US            M
# 68826                  US             0               US            M
# 68828                  US           100               US            M
# 68834                  US             0               US            M
# 68844                  US             0               US            M
# 68874                  US             0               US            M
# 68876                  US             0               US            M
# 68882                  US             0               US            M
# 78245                  GB             0               GB            M
# 82165                  US             0               US            M
# 89330                  MX             0               MX            M
# 106066                 GB             0               GB            M
# 106072                 US             0               US            M
# 114206                 US             0               US            M
# 115107                 US           100               US            M
# 117289                 US           100               US            M
# 120059                 US             0               US            M
# 120061                 US             0               US            M
# 122029                 US             0               US            M
# 127175                 US             0               US            M
# 127836                 CA           100               CA            M
# 128687                 US             0               US            M
# 129654                 US             0               US            M
# 130840                 US             0               US            M
# 130870                 US             0               US            M
# 130880                 US             0               US            M
# 130884                 US             0               US            M
# 131438                 US             0               US            M
# 131444                 US             0               US            M
# 132374                 US           100               US            M
# 132422                 US             0               US            M

# %%
df.loc[(df['experience_level']=='EX') & (df['salary']>600000)]
# Out:
#         work_year experience_level employment_type     job_title  \
# 51347  2025-01-01               EX              FT  Head of Data
# 104118 2024-01-01               EX              FT      Engineer
#
#        salary_currency  salary employee_residence  remote_ratio  \
# 51347              USD  625000                 US           100
# 104118             USD  609000                 US             0
#
#        company_location company_size
# 51347                US            M
# 104118               US            M

# %% [markdown]
# # Saving the final cleaned file
#
# `df.to_csv('xyz.csv',index=False)`

# %%
save_file='filtered_salary.csv'
df.to_csv(save_file,index=False)
